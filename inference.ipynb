# %%
from captum.attr import IntegratedGradients

# %%
# !pip install -e ../TrackSelectorDNN/ TrackSelectorDNN
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///eos/home-i03/e/ecoradin/GitHub/TrackSelectorDNN
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: TrackSelectorDNN
#     Found existing installation: TrackSelectorDNN 0.1
#     Uninstalling TrackSelectorDNN-0.1:
#       Successfully uninstalled TrackSelectorDNN-0.1
#   DEPRECATION: Legacy editable install of TrackSelectorDNN==0.1 from file:///eos/home-i03/e/ecoradin/GitHub/TrackSelectorDNN (setup.py develop) is deprecated. pip 25.0 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for TrackSelectorDNN
# ...

# %%
import json
import os
import pandas as pd
import matplotlib.pyplot as plt
import torch
from TrackSelectorDNN.models.track_classifier import TrackClassifier, TrackClassifierInference  
from TrackSelectorDNN.data_manager.dataset import TrackDatasetFromFile, collate_fn
from TrackSelectorDNN.models.preprocessing import FeaturePreprocessing

from sklearn.metrics import roc_curve, auc, confusion_matrix, accuracy_score, ConfusionMatrixDisplay
from scipy.stats import binomtest
import numpy as np
from torch.utils.data import DataLoader
import shap
import yaml
import onnxruntime as ort
import onnx

# %% [markdown]
# Manually look for the best model

# %%
run_root = "/eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/"
results = []

for trial_name in os.listdir(run_root):
    trial_dir = os.path.join(run_root, trial_name)
    metrics_file = os.path.join(trial_dir, "best_metrics.json")
    ckpt_file = os.path.join(trial_dir, "best_model.pt")
    config_file = os.path.join(trial_dir, "config.yaml")

    if os.path.exists(metrics_file):
        with open(metrics_file, "r") as f:
            metrics = json.load(f)

        val_loss = metrics.get("val_loss", None)
        if val_loss is not None:
            results.append({
                "trial": trial_name,
                "val_loss": val_loss,
                "ckpt": ckpt_file,
                "config": config_file if os.path.exists(config_file) else None
            })

# ---- Sort by val_loss ----
results_sorted = sorted(results, key=lambda x: x["val_loss"])

# ---- Take top 5 ----
top10 = results_sorted[:10]

# ---- Print results ----
print("\n=== Top 5 Networks by Lowest val_loss ===")
for i, r in enumerate(top10, 1):
    print(f"\n#{i}")
    print(f"Trial:      {r['trial']}")
    print(f"val_loss:   {r['val_loss']}")
    print(f"Checkpoint: {r['ckpt']}")
    print(f"Config:     {r['config']}")
# Out:
# === Top 5 Networks by Lowest val_loss ===
#
# #1
# Trial:      205c3_00130
# val_loss:   0.1945717559340746
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00130/best_model.pt
# Config:     /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00130/config.yaml
#
# #2
# Trial:      205c3_00132
# val_loss:   0.19461190637926565
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00132/best_model.pt
# Config:     /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00132/config.yaml
#
# #3
# Trial:      205c3_00148
# val_loss:   0.1947962403134392
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00148/best_model.pt
# Config:     /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00148/config.yaml
#
# #4
# Trial:      205c3_00253
# val_loss:   0.19490869869549374
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00253/best_model.pt
# ...

# %%
print("\n=== Top 5 Networks by Lowest val_loss ===")
for i, r in enumerate(top10, 1):
    print(f"\n#{i}  Trial: {r['trial']}")
    print(f"val_loss: {r['val_loss']}")
    print(f"Checkpoint: {r['ckpt']}")

    if r["config"] is None:
        print("Config: MISSING")
        continue

    # ---- Load config.yaml ----
    with open(r["config"], "r") as f:
        config = yaml.safe_load(f)

    # ---- Print requested fields ----
    print(
        config.get("lambda_sym", "MISSING"),
        config.get("netA_hidden_dim", "MISSING"),
        config.get("netA_hidden_layers", "MISSING"),
        config.get("latent_dim", "MISSING"),
        config.get("pooling_type", "MISSING"),
        config.get("netB_hidden_dim", "MISSING"),
        config.get("netB_hidden_layers", "MISSING"),
    )
# Out:
# === Top 5 Networks by Lowest val_loss ===
#
# #1  Trial: 205c3_00130
# val_loss: 0.1945717559340746
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00130/best_model.pt
# 0.008991365157064597 64 3 32 sum 128 3
#
# #2  Trial: 205c3_00132
# val_loss: 0.19461190637926565
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00132/best_model.pt
# 0.05911226532652397 64 3 32 sum 128 2
#
# #3  Trial: 205c3_00148
# val_loss: 0.1947962403134392
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00148/best_model.pt
# 0.00459054353142197 32 2 16 mean 32 3
#
# #4  Trial: 205c3_00253
# val_loss: 0.19490869869549374
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00253/best_model.pt
# 0.0020115041960831925 64 2 16 mean 32 3
#
# #5  Trial: 205c3_00305
# val_loss: 0.19493629561341827
# Checkpoint: /eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00305/best_model.pt
# 0.0006783166818150203 64 3 16 mean 32 3
#
# ...

# %%
PATH = '/eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs/205c3_00253/'
best_config = PATH + 'config.yaml'
best_ckpt_path = PATH + 'best_model.pt'
# Open and load YAML
with open(best_config, "r") as f:
    best_config = yaml.safe_load(f)

# %% [markdown]
# Load the validation dataset

# %%
base_path = '/eos/user/e/ecoradin/GitHub/TrackSelectorDNN/TrackSelectorDNN/data/'
train_ds = TrackDatasetFromFile(base_path+'tracks_train_dataset_inference.pt')
val_ds   = TrackDatasetFromFile(base_path+'tracks_val_dataset_inference.pt')

val_loader = DataLoader(val_ds, batch_size=best_config["batch_size"], collate_fn=collate_fn)
train_loader = DataLoader(train_ds, batch_size=best_config["batch_size"], collate_fn=collate_fn)

# %% [markdown]
# build the model

# %%
device='cpu'
base = TrackClassifier(hit_input_dim = best_config["hit_input_dim"],
                        track_feat_dim = best_config["track_feat_dim"],
                        latent_dim = best_config["latent_dim"],
                        pooling_type = best_config["pooling_type"],
                        # --- NetA parameters ---
                        netA_hidden_dim = best_config["netA_hidden_dim"],
                        netA_hidden_layers = best_config["netA_hidden_layers"],
                        netA_batchnorm = best_config["netA_batchnorm"],
                        netA_activation = best_config["netA_activation"],
                        # --- NetB parameters ---
                        netB_hidden_dim = best_config["netB_hidden_dim"],
                        netB_hidden_layers = best_config["netB_hidden_layers"],
                        netB_batchnorm = best_config["netB_batchnorm"],
                        netB_activation = best_config["netB_activation"]).to(device)


base.load_state_dict(torch.load(best_ckpt_path, map_location=device))
base.eval()
# Out:
# TrackClassifier(
#   (pool): MeanPooling()
#   (netA): NetA(
#     (mlp): Sequential(
#       (0): Linear(in_features=9, out_features=64, bias=True)
#       (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=64, out_features=64, bias=True)
#       (4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=64, out_features=16, bias=True)
#     )
#   )
#   (netB): NetB(
#     (mlp): Sequential(
#       (0): Linear(in_features=41, out_features=32, bias=True)
#       (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#       (3): Linear(in_features=32, out_features=32, bias=True)
#       (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (5): ReLU()
#       (6): Linear(in_features=32, out_features=32, bias=True)
# ...

# %%
 best_config
# Out:
# {'base_checkpoint_directory': '/eos/user/e/ecoradin/GitHub/TrackSelectorDNN/runs',
#  'batch_size': 128,
#  'dataset_type': 'production',
#  'delta': 0.0,
#  'dummy_load_path': None,
#  'epochs': 75,
#  'hit_input_dim': 9,
#  'idxSymRecHitFeatures': [2, 7],
#  'idxSymRecoPixelTrackFeatures': [5, 7, 10, 22, 23],
#  'lambda_sym': 0.0020115041960831925,
#  'latent_dim': 16,
#  'lr': 0.0017334529129498309,
#  'max_hits': 16,
#  'netA_activation': 'relu',
#  'netA_batchnorm': True,
#  'netA_hidden_dim': 64,
#  'netA_hidden_layers': 2,
#  'netB_activation': 'relu',
#  'netB_batchnorm': True,
#  'netB_hidden_dim': 32,
#  'netB_hidden_layers': 3,
#  'patience': 15,
#  'pooling_type': 'mean',
#  'test_path': '/eos/user/e/ecoradin/GitHub/TrackSelectorDNN/TrackSelectorDNN/data/tracks_test_dataset.pt',
#  'track_feat_dim': 25,
#  'train_path': '/eos/user/e/ecoradin/GitHub/TrackSelectorDNN/TrackSelectorDNN/data/tracks_train_dataset.pt',
# ...

# %%
pre_hit = FeaturePreprocessing(mean=train_ds.recHit_mean, std=train_ds.recHit_std, 
                                 clip_min=train_ds.clip_min_hit[0][0], clip_max=train_ds.clip_max_hit[0][0],
                                 do_log=train_ds.do_log_hit[0][0]
                              )

pre_track = FeaturePreprocessing(mean=train_ds.recoPixelTrack_mean, std=train_ds.recoPixelTrack_std, 
                                 clip_min=train_ds.clip_min_track[0][0], clip_max=train_ds.clip_max_track[0][0],
                                 do_log=train_ds.do_log_track[0][0])

# %%
model_inf = TrackClassifierInference(base, pre_hit, pre_track)
model_inf.eval()
# Out:
# TrackClassifierInference(
#   (base): TrackClassifier(
#     (pool): MeanPooling()
#     (netA): NetA(
#       (mlp): Sequential(
#         (0): Linear(in_features=9, out_features=64, bias=True)
#         (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Linear(in_features=64, out_features=64, bias=True)
#         (4): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
#         (6): Linear(in_features=64, out_features=16, bias=True)
#       )
#     )
#     (netB): NetB(
#       (mlp): Sequential(
#         (0): Linear(in_features=41, out_features=32, bias=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Linear(in_features=32, out_features=32, bias=True)
#         (4): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU()
# ...

# %%
dummy_hits   = torch.zeros(128, train_ds.MAX_HITS, best_config["hit_input_dim"])
dummy_tracks = torch.zeros(128, best_config["track_feat_dim"])

torch.onnx.export(
    model_inf,
    (dummy_hits, dummy_tracks),
    "track_classifier.onnx",
    input_names=["hits", "tracks"],
    output_names=["probabilities"],
    dynamic_axes={
        "hits": {0: "batch", 1: "nhits"},
        "tracks": {0: "batch"},
        "probabilities": {0: "batch"},
    },
    opset_version=17
)
# Out:
# /opt/conda/lib/python3.11/site-packages/torch/onnx/symbolic_opset9.py:2174: FutureWarning: 'torch.onnx.symbolic_opset9._cast_Bool' is deprecated in version 2.0 and will be removed in the future. Please Avoid using this function and create a Cast node instead.
#   return fn(g, to_cast_func(g, input, False), to_cast_func(g, other, False))

# %%
def plot_run_losses(run_dir):
    log_file = os.path.join(run_dir, "metrics.csv")  # or whatever CSVLogger writes
    if not os.path.exists(log_file):
        raise FileNotFoundError(f"No metrics.csv found in {run_dir}")

    df = pd.read_csv(log_file)

    # Assumes columns: epoch, train_loss, val_loss
    epochs = df["epoch"]
    train_loss = df["train_loss"]
    val_loss = df["val_loss"]

    plt.figure(figsize=(8,5))
    plt.plot(epochs, train_loss, label="Train Loss")
    plt.plot(epochs, val_loss, label="Validation Loss")

    plt.title("Training & Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()
    plt.grid(True)
    #plt.yscale('log')
    #plt.xscale('log')
    plt.show()

# %%
plot_run_losses(PATH)

# %% [markdown]
# Rerun inference

# %%
def predict(model, data_loader, device):
    all_preds = []

    with torch.no_grad():
        for batch in data_loader:
            hit_features = batch["hit_features"].to(device)
            track_features = batch["track_features"].to(device)
           
            preds = model(hit_features, track_features).cpu().numpy()
            all_preds.append(preds)
    
        all_preds = np.concatenate(all_preds)
    return all_preds

# %%
sess_options = ort.SessionOptions()
sess_options.intra_op_num_threads = 1  # or any number of threads you want
sess_options.inter_op_num_threads = 1

ort_session = ort.InferenceSession("track_classifier.onnx", sess_options)

def predict_onnx(ort_session, data_loader, device):
    all_preds = []

    for batch in data_loader:
        hit_features = batch["hit_features"].cpu().numpy()  # ONNX expects numpy
        track_features = batch["track_features"].cpu().numpy()
        
        ort_inputs = {
            "hits": hit_features,
            "tracks": track_features
        }
        preds = ort_session.run(None, ort_inputs)[0]  # list -> array
        all_preds.append(preds)
    
    return np.concatenate(all_preds)

# %%
all_preds = predict(model_inf, val_loader, device)
all_preds_train = predict(model_inf, train_loader, device)

onnx_preds_val = predict_onnx(ort_session, val_loader, device)
onnx_preds_train = predict_onnx(ort_session, train_loader, device)


all_isHighPurity = val_ds.isHighPurity.numpy()  
all_labels = val_ds.labels.numpy()  
all_labels_train = train_ds.labels.numpy()

# %%
# Compute max difference
max_diff_val = np.max(np.abs(all_preds - onnx_preds_val))
max_diff_train = np.max(np.abs(all_preds_train - onnx_preds_train))

print("Max diff (val):", max_diff_val)
print("Max diff (train):", max_diff_train)
# Out:
# Max diff (val): 2.026558e-06
# Max diff (train): 2.95043e-06

# %%
corr_val = np.corrcoef(all_preds.flatten(), onnx_preds_val.flatten())[0,1]
corr_train = np.corrcoef(all_preds_train.flatten(), onnx_preds_train.flatten())[0,1]

print("Correlation val:", corr_val)
print("Correlation train:", corr_train)
# Out:
# Correlation val: 0.9999999999999369
# Correlation train: 0.9999999999999358

# %%
# ROC curve
fpr_dnn, tpr_dnn, _ = roc_curve(all_labels, all_preds)
fpr_dnn_train, tpr_dnn_train, _ = roc_curve(all_labels_train, all_preds_train)

auc_dnn = auc(fpr_dnn, tpr_dnn)
auc_dnn_train = auc(fpr_dnn_train, tpr_dnn_train)

fpr_hp, tpr_hp, _ = roc_curve(all_labels, all_isHighPurity)
auc_hp = auc(fpr_hp, tpr_hp)

# Accuracy and confusion matrix for DNN
preds_bin = (all_preds > 0.095).astype(int)
acc_dnn = accuracy_score(all_labels, preds_bin)
tn, fp, fn, tp = confusion_matrix(all_labels, preds_bin, normalize='true').ravel()

print(f"✅ DNN Results:")
print(f"  AUC: {auc_dnn:.4f}")
print(f"  Accuracy: {acc_dnn:.4f}")
print(f"  True Positives:  {tp}")
print(f"  False Positives: {fp}")
print(f"  True Negatives:  {tn}")
print(f"  False Negatives: {fn}")
# Out:
# ✅ DNN Results:
#   AUC: 0.9760
#   Accuracy: 0.9306
#   True Positives:  0.9856372240791608
#   False Positives: 0.33154658678858584
#   True Negatives:  0.6684534132114142
#   False Negatives: 0.014362775920839262

# %%
# Accuracy for legacy classifier
acc_hp = accuracy_score(all_labels, all_isHighPurity)
tn_hp, fp_hp, fn_hp, tp_hp = confusion_matrix(all_labels, all_isHighPurity, normalize='true').ravel()

print(f"\n✅ Legacy (isHighPurity) Results:")
print(f"  AUC: {auc_hp:.4f}")
print(f"  Accuracy: {acc_hp:.4f}")
print(f"  True Positives:  {tp_hp}")
print(f"  False Positives: {fp_hp}")
print(f"  True Negatives:  {tn_hp}")
print(f"  False Negatives: {fn_hp}")
# Out:
# ✅ Legacy (isHighPurity) Results:
#   AUC: 0.6610
#   Accuracy: 0.8727
#   True Positives:  0.985140814773141
#   False Positives: 0.6630931735771717
#   True Negatives:  0.3369068264228283
#   False Negatives: 0.014859185226859053

# %%
plt.figure(figsize=(6, 5))
plt.plot(fpr_dnn, tpr_dnn, label=f"DNN (AUC = {auc_dnn:.3f})", color='blue')
plt.plot(fpr_hp, tpr_hp, label=f"Legacy HP (AUC = {auc_hp:.3f})", linestyle="dotted", color='red')
plt.plot(fpr_dnn_train, tpr_dnn_train, label=f"DNN (AUC = {auc_dnn_train:.3f})", linestyle="--", color='orange')
plt.plot([0, 1], [0, 1], "k--", alpha=0.3)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

ConfusionMatrixDisplay(confusion_matrix(all_labels, preds_bin, normalize='true')).plot(
    ax=axes[0], cmap="Blues", colorbar=False
)
axes[0].set_title("DNN Confusion Matrix")

ConfusionMatrixDisplay(confusion_matrix(all_labels, all_isHighPurity, normalize='true')).plot(
    ax=axes[1], cmap="Reds", colorbar=False
)
axes[1].set_title("Legacy isHighPurity Confusion Matrix")

for ax in axes:
    ax.set_xlabel("Predicted label")
    ax.set_ylabel("True label")

plt.tight_layout()
plt.show()

# %%
import numpy as np

scores = all_preds.flatten()
labels = all_labels.astype(int)

thresholds = np.linspace(0, 1, 200)

tpr_list = []   # P(pred=1 | true=1)
tnr_list = []   # P(pred=0 | true=0)

for t in thresholds:
    preds_bin = (scores > t).astype(int)

    # mask for classes
    mask0 = (labels == 0)
    mask1 = (labels == 1)

    # TPR
    if mask1.sum() > 0:
        tpr = preds_bin[mask1].mean()
    else:
        tpr = np.nan

    # TNR = P(pred=0 | true=0)
    if mask0.sum() > 0:
        tnr = (1 - preds_bin[mask0]).mean()
    else:
        tnr = np.nan

    tpr_list.append(tpr)
    tnr_list.append(tnr)

tpr_list = np.array(tpr_list)
tnr_list = np.array(tnr_list)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))
plt.plot(tnr_list, tpr_list, '-', label='DNN')
plt.plot(tn_hp, tp_hp, 'x', markersize=8, label='High Purity Selection')
plt.xlabel("TNR = P(pred=0 | true=0)")
plt.ylabel("TPR = P(pred=1 | true=1)")
plt.title("TPR vs TNR across thresholds")
plt.hlines(tp_hp,0,1,'red', 'dashed')
plt.grid(True)
plt.ylim(0.8, 1.025)
plt.tight_layout()
plt.legend(loc='lower left')
plt.show()

# %%
# indices where TPR >= required TPR
idx = np.where(tpr_list >= tp_hp)[0]

if len(idx) == 0:
    print("No threshold reaches the required TPR!")
else:
    # choose the *last* threshold that satisfies it (closest above tp_hp)
    best_idx = idx[-1]
    best_threshold = thresholds[best_idx]
    best_tpr = tpr_list[best_idx]
    best_tnr = tnr_list[best_idx]

    print("Threshold:", best_threshold)
    print("TPR:", best_tpr)
    print("TNR:", best_tnr)
# Out:
# Threshold: 0.09547738693467336
# TPR: 0.9855710361716914
# TNR: 0.6687687214251932

# %%
# Load previously exported binning
binning = np.loadtxt("/eos/user/e/ecoradin/sakura/examples/results/binning_fakeVsEta.txt", comments="#")

# Extract only the bin edges for compute_fake_rate
eta_bins = np.unique(np.concatenate([binning[:,0], binning[:,1]]))
eta_centers = 0.5 * (eta_bins[:-1] + eta_bins[1:])
external_fake = binning[:,2]
print("Loaded η bins")
# Out:
# Loaded η bins

# %%
def compute_fake_rate(y_true, y_pred_bin, eta, bins, cl=0.683):
    nbins = len(bins) - 1
    fake_rate = np.full(nbins, np.nan)
    fake_err_low = np.full(nbins, np.nan)
    fake_err_up  = np.full(nbins, np.nan)

    for i in range(nbins):
        sel = (eta >= bins[i]) & (eta < bins[i+1])
        if sel.sum() == 0:
            continue

        predicted_real = (y_pred_bin[sel] == 1)
        #print(predicted_real.shape, predicted_real.sum(), y_true[sel].sum())
        total = predicted_real.sum()
        if total == 0:
            continue

        fake = ((y_true[sel] == 0) & predicted_real).sum()

        # central value
        p = fake / total
        fake_rate[i] = p

        # binomial confidence interval
        result = binomtest(fake, total)
        ci = result.proportion_ci(confidence_level=cl)

        fake_err_low[i] = p - ci.low
        fake_err_up[i]  = ci.high - p
    
    return fake_rate, fake_err_low, fake_err_up

def compute_efficiency(y_true, y_pred_bin, eta, bins, cl=0.683):
    nbins = len(bins) - 1
    eff = np.full(nbins, np.nan)
    eff_err_low = np.full(nbins, np.nan)
    eff_err_up  = np.full(nbins, np.nan)

    for i in range(nbins):
        sel = (eta >= bins[i]) & (eta < bins[i+1])

        true_sel = sel & (y_true == 1)
        total = true_sel.sum()
        if total == 0:
            continue

        passed = (y_pred_bin[true_sel] == 1).sum()

        # central value
        p = passed / total
        eff[i] = p

        # binomial confidence interval
        result = binomtest(passed, total)
        ci = result.proportion_ci(confidence_level=cl)

        eff_err_low[i] = p - ci.low
        eff_err_up[i]  = ci.high - p

    return eff, eff_err_low, eff_err_up

# --- Recover raw η ---
eta_idx = val_ds.recoPixelTrackBranches.index("hltPixelTrack_eta")

eta_norm = val_ds.recoPixelTrackFeatures[:, eta_idx].numpy()
eta_mean = val_ds.recoPixelTrack_mean[0, eta_idx].numpy()
eta_std  = val_ds.recoPixelTrack_std[0, eta_idx].numpy()

eta_vals = eta_norm * eta_std + eta_mean   # <-- raw η

# --- Threshold predictions ---
preds_bin = (all_preds > 0.095).astype(int)
labels = all_labels.astype(int)
hp = all_isHighPurity.astype(int)

# --- Binomial CI fake rates ---
print('---- DNN ') 
fake_rate_dnn, fake_low_dnn, fake_up_dnn = compute_fake_rate(labels, preds_bin, eta_vals, eta_bins)
print('---- HP ')
fake_rate_hp,  fake_low_hp,  fake_up_hp  = compute_fake_rate(labels, hp,       eta_vals, eta_bins)
print('---- Worst ')
fake_rate_worst,  fake_low_worst,  fake_up_worst  = compute_fake_rate(labels, np.ones_like(labels),       eta_vals, eta_bins)

# --- Binomial CI efficiency ---
eff_dnn, eff_low_dnn, eff_up_dnn = compute_efficiency(labels, preds_bin, eta_vals, eta_bins)
eff_hp,  eff_low_hp,  eff_up_hp  = compute_efficiency(labels, hp,       eta_vals, eta_bins)
# Out:
# ---- DNN
# ---- HP
# ---- Worst

# %%
# --- Plot Fake Rate ---
plt.figure(figsize=(7,5))
plt.errorbar(
    eta_centers, fake_rate_dnn,
    yerr=[fake_low_dnn, fake_up_dnn],
    fmt='o-', label='DNN', alpha=0.8, color='blue',
)

plt.errorbar(
    eta_centers, fake_rate_hp,
    yerr=[fake_low_hp, fake_up_hp],
    fmt='s--', label='High Purity Selection', alpha=0.8, color = 'red'
)
#plt.errorbar(
#    eta_centers, fake_rate_worst,
#    yerr=[fake_low_worst, fake_up_worst],
#    fmt='s--', label='Worst classifier', alpha=0.8
#)
#plt.plot(eta_centers, external_fake)
plt.xlabel('Track η')
plt.ylabel('Fake Rate')
plt.title('Fake Rate vs η')
plt.grid(True, alpha=0.3)
plt.legend()
plt.ylim(0,0.4)
plt.tight_layout()
plt.show()

# %%
# --- Plot Efficiency ---
plt.figure(figsize=(7,5))
plt.errorbar(
    eta_centers, eff_dnn,
    yerr=[eff_low_dnn, eff_up_dnn],
    fmt='o-', label='DNN', color='blue', alpha=0.8
)

plt.errorbar(
    eta_centers, eff_hp,
    yerr=[eff_low_hp, eff_up_hp],
    fmt='o-', label='High Purity', color='red', alpha=0.8
)
plt.xlabel('Track η')
plt.ylabel('Efficiency')
plt.title('True-Track Efficiency vs η')
plt.grid(True, alpha=0.3)
plt.legend()
plt.ylim(0.90, 1.05)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix

tn_hp, fp_hp, fn_hp, tp_hp = confusion_matrix(all_labels, hp).ravel()
tpr_hp = tp_hp / (tp_hp + fn_hp)

print("Legacy TPR:", tpr_hp)
fpr, tpr, thresholds = roc_curve(all_labels, all_preds)
idx = np.argmin(np.abs(tpr - tpr_hp))

best_threshold = thresholds[idx]
tpr_dnn_at_best = tpr[idx]
fpr_dnn_at_best = fpr[idx]

print("Best DNN threshold:", best_threshold)
print("DNN TPR at matched point:", tpr_dnn_at_best)
print("DNN FPR at matched point:", fpr_dnn_at_best)
# Out:
# Legacy TPR: 0.985140814773141
# Best DNN threshold: 0.0982124
# DNN TPR at matched point: 0.985140814773141
# DNN FPR at matched point: 0.3242944978716696

# %%
ratio = np.array(eff_dnn)/np.array(eff_hp)
np.nanmin(ratio), np.nanmax(ratio)
# Out:
# (0.9675324675324676, 1.0316455696202531)

# %%
import matplotlib.pyplot as plt

all_probs = []
current_probs = []

with open("probabilities.txt", "r") as f:
    for line in f:
        line = line.strip()

        # New event starts
        if line.startswith("Event"):
            current_probs = []

        # End of event block
        elif line == "----":
            all_probs.extend(current_probs)

        # Probability line
        else:
            try:
                p = float(line)
                current_probs.append(p)
            except ValueError:
                pass  # ignore anything not a float

# Convert to numpy array if needed
import numpy as np
all_probs = np.array(all_probs)

# Plot
plt.figure(figsize=(7,5))
plt.hist(all_preds[:20000], bins=50, density=True)
plt.hist(all_probs, bins=50, density=True)
plt.xlabel("Probability")
plt.ylabel("pdf")
plt.title("Distribution of Track Probabilities")
plt.grid(True)
plt.show()

# %%
# -----------------------
# SAFE PREPROCESSING UTIL
# -----------------------
def preprocess_batch(hits, tracks):
    """
    Run the same preprocessing your inference wrapper uses.
    Returns (hits_clean, tracks_clean) on the same device as inputs.
    """
    # Move to device if not there
    hits = hits.to(device)
    tracks = tracks.to(device)

    # Preprocessing modules from your TrackClassifierInference
    hits_clean = model_inf.pre_hit(hits)
    tracks_clean = model_inf.pre_track(tracks)

    # sanitize NaNs (the inference forward does this)
    tracks_clean = torch.nan_to_num(tracks_clean, nan=0.0)
    hits_clean = torch.nan_to_num(hits_clean, nan=0.0)

    return hits_clean, tracks_clean

# -----------------------
# FORWARD WRAPPERS FOR CAPTUM
# -----------------------
# Captum will call forward_tracks(tracks, hits) when attributing to tracks
def forward_tracks(tracks, hits):
    # tracks: Tensor (B, track_feat_dim)
    # hits: passed via additional_forward_args, shape (B, N_hits, hit_dim)
    out = model_inf(hits, tracks)  # model_inf returns probs (B,) or (B,1) depending
    # Ensure shape (B,) for Captum
    return out.view(out.shape[0])

# Captum will call forward_hits(hits, tracks) when attributing to hits
def forward_hits(hits, tracks):
    out = model_inf(hits, tracks)
    return out.view(out.shape[0])

# Instantiate IGs
ig_tracks = IntegratedGradients(forward_tracks)
ig_hits   = IntegratedGradients(forward_hits)

# -----------------------
# PER-SAMPLE ATTRIBUTION FUNCTIONS
# -----------------------
def ig_track_importance_single(hits, tracks, baseline_value=0.0, n_steps=50):
    """
    Compute IG attributions for track features for a single sample (batch size 1).
    Returns numpy array shape (track_feat_dim,).
    """
    hits_clean, tracks_clean = preprocess_batch(hits, tracks)
    # We compute attributions wrt tracks only; hits passed as additional_forward_args
    baseline_tracks = torch.zeros_like(tracks_clean) + baseline_value
    # Keep batch dimension (1)
    attr_tracks = ig_tracks.attribute(
        inputs=tracks_clean,
        baselines=baseline_tracks,
        additional_forward_args=(hits_clean,),
        n_steps=n_steps,
        internal_batch_size=1
    )
    # attr_tracks shape: (B, track_feat_dim) -> return first sample
    return attr_tracks.detach().cpu().numpy()[0]

def ig_hit_importance_single(hits, tracks, baseline_value=0.0, n_steps=50):
    """
    Compute IG attributions for hits (shape: N_hits x hit_feat_dim) for a single sample (batch size 1).
    Returns numpy array shape (N_hits, hit_feat_dim).
    """
    hits_clean, tracks_clean = preprocess_batch(hits, tracks)
    baseline_hits = torch.zeros_like(hits_clean) + baseline_value
    attr_hits = ig_hits.attribute(
        inputs=hits_clean,
        baselines=baseline_hits,
        additional_forward_args=(tracks_clean,),
        n_steps=n_steps,
        internal_batch_size=1
    )
    # attr_hits shape: (B, N_hits, hit_feat_dim) -> return first sample
    return attr_hits.detach().cpu().numpy()[0]

def hit_level_importance_from_attr(attr_hits):
    """
    Reduce hit-feature attributions to per-hit importance by summing absolute values over feature dims.
    attr_hits: (N_hits, hit_feat_dim)
    returns: (N_hits,)
    """
    return np.sum(np.abs(attr_hits), axis=-1)

# -----------------------
# DATASET-LEVEL AGGREGATION
# -----------------------
def compute_dataset_track_importance(loader, max_batches=None, n_steps=50):
    """
    Returns mean absolute IG attribution per track feature across the dataset.
    """
    all_imp = []
    for i, batch in enumerate(tqdm(loader, desc="Track IG over dataset")):
        if max_batches is not None and i >= max_batches:
            break
        hits = batch["hit_features"].to(device)
        tracks = batch["track_features"].to(device)
        B = hits.shape[0]
        for b in range(B):
            imp = ig_track_importance_single(hits[b:b+1], tracks[b:b+1], n_steps=n_steps)
            all_imp.append(np.abs(imp))
    all_imp = np.stack(all_imp)  # (n_samples, track_feat_dim)
    mean_imp = np.mean(all_imp, axis=0)
    return mean_imp

def compute_dataset_hit_feature_importance(loader, max_batches=None, n_steps=50):
    """
    Returns mean absolute IG attribution per hit-feature dimension across the dataset.
    This collapses hits and averages per-feature (hit_feat_dim).
    """
    all_imp = []
    for i, batch in enumerate(tqdm(loader, desc="Hit IG over dataset")):
        if max_batches is not None and i >= max_batches:
            break
        hits = batch["hit_features"].to(device)
        tracks = batch["track_features"].to(device)
        B = hits.shape[0]
        for b in range(B):
            attr_hits = ig_hit_importance_single(hits[b:b+1], tracks[b:b+1], n_steps=n_steps)
            # Sum over hits to get per-feature contribution for this sample
            per_feature = np.sum(np.abs(attr_hits), axis=0)  # (hit_feat_dim,)
            all_imp.append(per_feature)
    all_imp = np.stack(all_imp)
    mean_per_feature = np.mean(all_imp, axis=0)
    return mean_per_feature

# -----------------------
# PLOTTING UTILITIES
# -----------------------
def plot_bar(values, labels=None, title="", ylabel="importance", save_path=None):
    plt.figure(figsize=(10,4))
    x = np.arange(len(values))
    plt.bar(x, values)
    if labels is not None:
        plt.xticks(x, labels, rotation=90)
    plt.ylabel(ylabel)
    plt.title(title)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150)
    plt.show()

def plot_hit_heatmap(attr_hits, title="Hit feature attributions", save_path=None):
    plt.figure(figsize=(8,6))
    plt.imshow(np.abs(attr_hits), aspect='auto')
    plt.colorbar(label="|IG|")
    plt.xlabel("Hit feature dim")
    plt.ylabel("Hit index")
    plt.title(title)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150)
    plt.show()

def plot_hit_importance(hit_imp, title="Hit importance (sum over features)", save_path=None):
    plt.figure(figsize=(8,3))
    plt.plot(hit_imp, marker='o')
    plt.xlabel("Hit index")
    plt.ylabel("Importance")
    plt.title(title)
    plt.grid(True)
    plt.tight_layout()
    if save_path:
        plt.savefig(save_path, dpi=150)
    plt.show()

# -----------------------
# EXAMPLE: RUN ON A SINGLE BATCH / SAMPLE
# -----------------------
# Use one batch to demonstrate per-sample plots
batch = next(iter(val_loader))
hits = batch["hit_features"][:1]    # first sample
tracks = batch["track_features"][:1] # first sample

print("Computing IG for a single sample (this may take a few seconds depending on n_steps)...")
track_imp_sample = ig_track_importance_single(hits, tracks, n_steps=50)  # shape (track_feat_dim,)
hit_attr_sample = ig_hit_importance_single(hits, tracks, n_steps=50)     # shape (N_hits, hit_feat_dim)
hit_imp_sample  = hit_level_importance_from_attr(hit_attr_sample)        # shape (N_hits,)

# Plot results (adjust feature names if you have them)
try:
    track_feature_names = getattr(val_loader.dataset, "track_feature_names", None)
except Exception:
    track_feature_names = None

plot_bar(track_imp_sample, labels=track_feature_names, title="Sample: Track feature IG (abs mean)")
plot_hit_heatmap(hit_attr_sample, title="Sample: Hit feature IG heatmap (abs values)")
plot_hit_importance(hit_imp_sample, title="Sample: Hit importance (abs sum)")

# -----------------------
# DATASET AGGREGATION (OPTIONAL, time-consuming)
# -----------------------
# Set max_batches to limit runtime during exploratory runs (e.g., 20).
# Set max_batches=None to run over entire loader.
max_batches = 20  # change to None for full evaluation
n_steps = 50      # IG steps (increase for smoother attributions)

print("Aggregating track-feature importance over dataset (may be slow)...")
mean_track_imp = compute_dataset_track_importance(val_loader, max_batches=max_batches, n_steps=n_steps)
print("Aggregating hit-feature importance over dataset (may be slow)...")
mean_hit_feature_imp = compute_dataset_hit_feature_importance(val_loader, max_batches=max_batches, n_steps=n_steps)

# Plot aggregated results
plot_bar(mean_track_imp, labels=track_feature_names, title=f"Dataset mean track-feature importance (over {max_batches} batches)", save_path="mean_track_imp.png")
plot_bar(mean_hit_feature_imp, labels=[f"h{i}" for i in range(len(mean_hit_feature_imp))], title=f"Dataset mean hit-feature importance (over {max_batches} batches)", save_path="mean_hit_feature_imp.png")
# Out:
# Computing IG for a single sample (this may take a few seconds depending on n_steps)...
# Aggregating track-feature importance over dataset (may be slow)...
# Track IG over dataset:   7%|▋         | 20/286 [01:57<26:04,  5.88s/it]
# Aggregating hit-feature importance over dataset (may be slow)...
# Hit IG over dataset:   7%|▋         | 20/286 [02:16<30:17,  6.83s/it]
